# %%
import json
import pandas as pd
import numpy as np

# %%
# read in data
brands = pd.read_csv("../CSV Tables/brands.csv")
categories = pd.read_csv("../CSV Tables/categories.csv")
users = pd.read_csv("../CSV Tables/users.csv")
cpgs = pd.read_csv("../CSV Tables/cpgs.csv")
receipts = pd.read_csv("../CSV Tables/receipts.csv")
receipt_items = pd.read_csv("../CSV Tables/receipt_items.csv")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (1,5,7,10,14,15,16,17,18,19,21,22,23,30,33,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# receipts
receipts.describe()
# Out:
#         Unnamed: 0  bonusPointsEarned    createDate   dateScanned  \
# count  1119.000000         544.000000  1.119000e+03  1.119000e+03
# mean    559.000000         238.893382  1.611800e+12  1.611800e+12
# std     323.171781         299.091731  1.484091e+09  1.484091e+09
# min       0.000000           5.000000  1.604089e+12  1.604089e+12
# 25%     279.500000           5.000000  1.610652e+12  1.610652e+12
# 50%     559.000000          45.000000  1.611941e+12  1.611941e+12
# 75%     838.500000         500.000000  1.612704e+12  1.612704e+12
# max    1118.000000         750.000000  1.614641e+12  1.614641e+12
#
#        finishedDate    modifyDate  pointsAwardedDate  pointsEarned  \
# count  5.680000e+02  1.119000e+03       5.370000e+02    609.000000
# mean   1.611058e+12  1.611847e+12       1.610949e+12    585.962890
# std    9.534641e+08  1.361576e+09       1.056718e+09   1357.166947
# min    1.609687e+12  1.609687e+12       1.604089e+12      0.000000
# 25%    1.610141e+12  1.610660e+12       1.610043e+12      5.000000
# 50%    1.611091e+12  1.611941e+12       1.611090e+12    150.000000
# 75%    1.611769e+12  1.612704e+12       1.611710e+12    750.000000
# max    1.614379e+12  1.614641e+12       1.614379e+12  10199.800000
#
#        purchaseDate  purchasedItemCount   totalSpent
# count  6.710000e+02           635.00000   684.000000
# mean   1.608548e+12            14.75748    77.796857
# std    1.230755e+10            61.13424   347.110349
# min    1.509322e+12             0.00000     0.000000
# 25%    1.609805e+12             1.00000     1.000000
# 50%    1.610551e+12             2.00000    18.200000
# 75%    1.611624e+12             5.00000    34.960000
# max    1.615225e+12           689.00000  4721.950000

# %%
receipts.head()
# Out:
#    Unnamed: 0                       _id  bonusPointsEarned  \
# 0           0  5ff1e1eb0a720f0523000575              500.0
# 1           1  5ff1e1bb0a720f052300056b              150.0
# 2           2  5ff1e1f10a720f052300057a                5.0
# 3           3  5ff1e1ee0a7214ada100056f                5.0
# 4           4  5ff1e1d20a7214ada1000561                5.0
#
#                              bonusPointsEarnedReason     createDate  \
# 0  Receipt number 2 completed, bonus point schedu...  1609687531000
# 1  Receipt number 5 completed, bonus point schedu...  1609687483000
# 2                         All-receipts receipt bonus  1609687537000
# 3                         All-receipts receipt bonus  1609687534000
# 4                         All-receipts receipt bonus  1609687506000
#
#      dateScanned  finishedDate     modifyDate  pointsAwardedDate  \
# 0  1609687531000  1.609688e+12  1609687536000       1.609688e+12
# 1  1609687483000  1.609687e+12  1609687488000       1.609687e+12
# 2  1609687537000           NaN  1609687542000                NaN
# 3  1609687534000  1.609688e+12  1609687539000       1.609688e+12
# 4  1609687506000  1.609688e+12  1609687511000       1.609688e+12
#
#    pointsEarned  purchaseDate  purchasedItemCount rewardsReceiptStatus  \
# 0         500.0  1.609632e+12                 5.0             FINISHED
# 1         150.0  1.609601e+12                 2.0             FINISHED
# 2           5.0  1.609632e+12                 1.0             REJECTED
# 3           5.0  1.609632e+12                 4.0             FINISHED
# 4           5.0  1.609601e+12                 2.0             FINISHED
#
#    totalSpent                    userId
# 0        26.0  5ff1e1eacfcf6c399c274ae6
# 1        11.0  5ff1e194b6a9d73a3a9f1052
# 2        10.0  5ff1e1f1cfcf6c399c274b0b
# 3        28.0  5ff1e1eacfcf6c399c274ae6
# 4         1.0  5ff1e194b6a9d73a3a9f1052

# %% [markdown]
# ### Receipt Items

# %%
receipt_items.describe()
# Out:
#          Unnamed: 0    finalPrice     itemPrice  partnerItemId  \
# count  1.156991e+06  1.155550e+06  1.155550e+06   1.156991e+06
# mean   1.439338e+02  8.226569e+00  8.227137e+00   1.294992e+03
# std    1.186707e+02  1.937742e+01  1.937728e+01   2.493509e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.200000e+01  2.240000e+00  2.240000e+00   1.128000e+03
# 50%    1.080000e+02  3.990000e+00  3.990000e+00   1.241000e+03
# 75%    2.090000e+02  7.560000e+00  7.560000e+00   1.416000e+03
# max    4.580000e+02  4.415800e+02  4.415800e+02   2.043000e+03
#
#        quantityPurchased  userFlaggedBarcode  userFlaggedPrice  \
# count       1.155550e+06        1.839000e+03       1777.000000
# mean        1.436680e+00        3.191073e+10         25.673585
# std         1.371498e+00        1.277561e+10          8.249304
# min         1.000000e+00        1.234000e+03          1.000000
# 25%         1.000000e+00        3.410057e+10         29.000000
# 50%         1.000000e+00        3.410057e+10         29.000000
# 75%         1.000000e+00        3.410057e+10         29.000000
# max         1.700000e+01        7.940007e+10         29.000000
#
#        userFlaggedQuantity  originalMetaBriteBarcode  discountedItemPrice  \
# count          1777.000000              9.800000e+01         1.149258e+06
# mean              1.196398              3.262633e+10         8.229648e+00
# std               0.688735              2.977639e+10         1.941904e+01
# min               1.000000              2.900002e+09         1.600000e-01
# 25%               1.000000              2.900002e+09         2.280000e+00
# 50%               1.000000              3.410057e+10         3.990000e+00
# 75%               1.000000              6.546912e+10         7.490000e+00
# max               5.000000              8.087804e+10         4.415800e+02
#
#          itemNumber  originalMetaBriteQuantityPurchased  pointsEarned  \
# count  1.963000e+03                           51.000000  76729.000000
# mean   1.232692e+11                            1.294118     90.008409
# std    2.347647e+11                            0.460179    128.507124
# min    4.011000e+03                            1.000000      4.500000
# 25%    9.800001e+08                            1.000000     33.800000
# 50%    3.746602e+10                            1.000000     55.800000
# 75%    7.874211e+10                            2.000000     93.000000
# max    8.872140e+11                            2.000000    870.000000
#
#        targetPrice  originalFinalPrice  originalMetaBriteItemPrice  \
# count  2170.000000           45.000000                   45.000000
# mean    548.449309            4.000000                    4.000000
# std     344.453300            4.290582                    4.290582
# min      77.000000            1.000000                    1.000000
# 25%      77.000000            1.000000                    1.000000
# 50%     800.000000            1.000000                    1.000000
# 75%     800.000000           10.000000                   10.000000
# max     800.000000           10.000000                   10.000000
#
#        priceAfterCoupon
# count     269178.000000
# mean           9.423520
# std           22.317822
# min            0.190000
# 25%            2.340000
# 50%            4.000000
# 75%            8.000000
# max          245.000000

# %%
receipt_items.head()
# Out:
#    Unnamed: 0      barcode                                        description  \
# 0           0         4011                                     ITEM NOT FOUND
# 1           0         4011                                     ITEM NOT FOUND
# 2           1  2.84006e+10  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...
# 3           0         4011                                     ITEM NOT FOUND
# 4           1  2.84006e+10  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...
#
#    finalPrice  itemPrice needsFetchReview  partnerItemId  \
# 0        26.0       26.0            False              1
# 1         1.0        1.0              NaN              1
# 2        10.0       10.0             True              2
# 3         1.0        1.0              NaN              1
# 4        10.0       10.0             True              2
#
#   preventTargetGapPoints  quantityPurchased  userFlaggedBarcode  ...  \
# 0                   True                5.0        4.011000e+03  ...
# 1                    NaN                1.0                 NaN  ...
# 2                   True                1.0        2.840064e+10  ...
# 3                    NaN                1.0                 NaN  ...
# 4                   True                1.0        2.840064e+10  ...
#
#   itemNumber  originalMetaBriteQuantityPurchased  pointsEarned targetPrice  \
# 0        NaN                                 NaN           NaN         NaN
# 1        NaN                                 NaN           NaN         NaN
# 2        NaN                                 NaN           NaN         NaN
# 3        NaN                                 NaN           NaN         NaN
# 4        NaN                                 NaN           NaN         NaN
#
#   competitiveProduct originalFinalPrice originalMetaBriteItemPrice deleted  \
# 0                NaN                NaN                        NaN     NaN
# 1                NaN                NaN                        NaN     NaN
# 2                NaN                NaN                        NaN     NaN
# 3                NaN                NaN                        NaN     NaN
# 4                NaN                NaN                        NaN     NaN
#
#   priceAfterCoupon metabriteCampaignId
# 0              NaN                 NaN
# 1              NaN                 NaN
# 2              NaN                 NaN
# 3              NaN                 NaN
# 4              NaN                 NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Users

# %%
# users
users.describe()
# Out:
#        Unnamed: 0   createdDate     lastLogin
# count  495.000000  4.950000e+02  4.330000e+02
# mean   247.000000  1.596678e+12  1.611388e+12
# std    143.038456  4.402970e+10  4.430109e+09
# min      0.000000  1.418999e+12  1.525714e+12
# 25%    123.500000  1.609789e+12  1.610130e+12
# 50%    247.000000  1.610569e+12  1.611237e+12
# 75%    370.500000  1.611596e+12  1.612366e+12
# max    494.000000  1.613139e+12  1.614963e+12

# %%
users.head()
# Out:
#    Unnamed: 0                       _id  active    createdDate     lastLogin  \
# 0           0  5ff1e194b6a9d73a3a9f1052    True  1609687444800  1.609688e+12
# 1           1  5ff1e194b6a9d73a3a9f1052    True  1609687444800  1.609688e+12
# 2           2  5ff1e194b6a9d73a3a9f1052    True  1609687444800  1.609688e+12
# 3           3  5ff1e1eacfcf6c399c274ae6    True  1609687530554  1.609688e+12
# 4           4  5ff1e194b6a9d73a3a9f1052    True  1609687444800  1.609688e+12
#
#        role signUpSource state
# 0  consumer        Email    WI
# 1  consumer        Email    WI
# 2  consumer        Email    WI
# 3  consumer        Email    WI
# 4  consumer        Email    WI

# %%
users['active'].value_counts()
# Out:
# True     494
# False      1
# Name: active, dtype: int64

# %%
users['role'].value_counts()
# Out:
# consumer       413
# fetch-staff     82
# Name: role, dtype: int64

# %%
users['state'].value_counts()
# Out:
# WI    396
# NH     20
# AL     12
# OH      5
# IL      3
# CO      1
# SC      1
# KY      1
# Name: state, dtype: int64

# %%
receipt_users = receipts[['userId']].drop_duplicates()
receipt_users['_id'] = receipt_users['userId']
user_merge = receipts.merge(users, how='inner', on=['_id'])
user_merge
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, _id, bonusPointsEarned, bonusPointsEarnedReason, createDate, dateScanned, finishedDate, modifyDate, pointsAwardedDate, pointsEarned, purchaseDate, purchasedItemCount, rewardsReceiptStatus, totalSpent, userId, Unnamed: 0_y, active, createdDate, lastLogin, role, signUpSource, state]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Brands

# %%
brands.describe()
# Out:
#         Unnamed: 0       barcode        cpgId
# count  1167.000000  1.167000e+03  1167.000000
# mean    583.000000  5.111115e+11    59.423308
# std     337.028189  2.874497e+05    58.997797
# min       0.000000  5.111110e+11     1.000000
# 25%     291.500000  5.111112e+11    11.500000
# 50%     583.000000  5.111114e+11    29.000000
# 75%     874.500000  5.111117e+11   104.500000
# max    1166.000000  5.111119e+11   204.000000

# %%
brands
# Out:
#       Unnamed: 0                       _id       barcode  cpgId
# 0              0  601ac115be37ce2ead437551  511111019862    202
# 1              1  601c5460be37ce2ead43755f  511111519928      7
# 2              2  601ac142be37ce2ead43755d  511111819905    203
# 3              3  601ac142be37ce2ead43755a  511111519874    203
# 4              4  601ac142be37ce2ead43755e  511111319917     17
# ...          ...                       ...           ...    ...
# 1162        1162  5f77274dbe37ce6b592e90c0  511111116752    113
# 1163        1163  5dc1fca91dda2c0ad7da64ae  511111706328     24
# 1164        1164  5f494c6e04db711dd8fe87e7  511111416173     17
# 1165        1165  5a021611e4b00efe02b02a57  511111400608      6
# 1166        1166  6026d757be37ce6369301468  511111019930    204
#
# [1167 rows x 4 columns]

# %%
barcodes_test = barcodes['barcode'].drop_duplicates()
barcodes_test
# Out:
# 0       511111019862
# 1       511111519928
# 2       511111819905
# 3       511111519874
# 4       511111319917
#             ...
# 1162    511111116752
# 1163    511111706328
# 1164    511111416173
# 1165    511111400608
# 1166    511111019930
# Name: barcode, Length: 1160, dtype: int64
